# %%
using ImageFeatures, Images, FileIO;
# Out:
# ┌ Info: Precompiling ImageFeatures [92ff4b2b-8094-53d3-b29d-97f740f06cef]
# └ @ Base loading.jl:1186

# %%
left = load("../data/dense/0000-small-left.png")
right = load("../data/dense/0001-small-right.png");

# %%
[left right]
# Out:
# 683×2048 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.624,0.686,0.89)   …  RGB{N0f8}(0.604,0.671,0.843)
#  RGB{N0f8}(0.62,0.686,0.89)       RGB{N0f8}(0.604,0.671,0.839)
#  RGB{N0f8}(0.616,0.682,0.89)      RGB{N0f8}(0.6,0.667,0.839)
#  RGB{N0f8}(0.616,0.69,0.89)       RGB{N0f8}(0.604,0.671,0.843)
#  RGB{N0f8}(0.624,0.69,0.894)      RGB{N0f8}(0.6,0.671,0.839)
#  RGB{N0f8}(0.612,0.69,0.886)   …  RGB{N0f8}(0.608,0.675,0.851)
#  RGB{N0f8}(0.608,0.686,0.886)     RGB{N0f8}(0.608,0.675,0.847)
#  RGB{N0f8}(0.608,0.682,0.882)     RGB{N0f8}(0.608,0.675,0.851)
#  RGB{N0f8}(0.612,0.678,0.882)     RGB{N0f8}(0.604,0.675,0.855)
#  RGB{N0f8}(0.62,0.682,0.882)      RGB{N0f8}(0.608,0.675,0.855)
#  RGB{N0f8}(0.62,0.682,0.886)   …  RGB{N0f8}(0.608,0.675,0.855)
#  RGB{N0f8}(0.616,0.678,0.886)     RGB{N0f8}(0.616,0.675,0.859)
#  RGB{N0f8}(0.62,0.682,0.886)      RGB{N0f8}(0.62,0.682,0.863)
#  ⋮                             ⋱
# ...

# %%
size(left), size(right)
# Out:
# ((683, 1024), (683, 1024))
